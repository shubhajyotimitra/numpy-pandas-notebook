# %%
# Random Numbers in NumPy :

# %%
from numpy import random

x = random.randint(100)

print(x)
# Out:
# 80

# %%
from numpy import random

x = random.rand()

print(x)
# Out:
# 0.07298581427996065

# %%
# Generate Random Array :
